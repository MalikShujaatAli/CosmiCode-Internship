# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

titanic = pd.read_csv("D:\\CosmiCode Internship\\Week 3\\Titanic-Dataset.csv")

# %%
print(titanic.head())

# %%
sns.countplot(x='Pclass', hue='Survived', data=titanic, palette='Set2')
plt.title('Survival Count by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(titanic['Age'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title('Age Distribution of Titanic Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sex_counts = titanic['Sex'].value_counts()
plt.pie(sex_counts, labels=sex_counts.index, autopct='%1.1f%%', colors=["#1eaff1", "#fb0abf"])
plt.title('Proportion of Passengers by Sex')
plt.axis('equal')
plt.show()

# %%
plt.scatter(titanic['Age'], titanic['Fare'], color='purple', alpha=0.5)
plt.title('Age vs. Fare of Titanic Passengers')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.grid(True)
plt.show()

# %%
numeric_cols = titanic[['Age', 'Fare', 'SibSp', 'Parch']].dropna()
correlation_matrix = numeric_cols.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap of Titanic Numeric Variables')
plt.show()

# %%
sns.pairplot(titanic[['Age', 'Fare', 'SibSp', 'Parch']].dropna())
plt.suptitle('Pair Plot of Titanic Numeric Variables', y=1.02)
plt.show()
